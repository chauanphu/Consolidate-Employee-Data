# %% [markdown]
# You just got hired as the first and only data practitioner at a small business experiencing exponential growth. The company needs more structured processes, guidelines, and standards. Your first mission is to structure the human resources data. The data is currently scattered across teams and files and comes in various formats: Excel files, CSVs, JSON files...
#
# You'll work with the following data in the `datasets' folder:
# - __Office addresses__ are currently saved in 'office_addresses.csv'. If the value for office is 'NaN', then the employee is remote.
# - __Employee addresses__ are saved on the first tab of `employee_information.xlsx`.
# - __Employee emergency contacts__ are saved on the second tab of `employee_information.xlsx`; this tab is called `emergency_contacts`. However, this sheet was edited at some point, and the headers were removed! The HR manager let you know that they should be: `employee_id`, `last_name`, `first_name`, `emergency_contact`, `emergency_contact_number`, and `relationship`.
# - __Employee roles, teams, and salaries__ have been exported from the company's human resources management system into a JSON file titled `employee_roles.json`. Here are the first few lines of that file:
# ```
# {"A2R5H9":
#   {
#     "title": "CEO",
#     "monthly_salary": "$4500",
#     "team": "Leadership"
#   },
#  ...
# }

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\projects\data science & ml\env\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in d:\projects\data science & ml\env\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## I. Import data 📩

# %% [markdown]
# Firstly, we will read from multiple sources and store them to temporary dataframe

# %%
import pandas as pd

# %%
employee_address_df = pd.read_excel('./datasets/employee_information.xlsx',
                                    sheet_name='employee_addresses',
                                    index_col='employee_id')
employee_address_df.head()
# Out:
#             employee_last_name employee_first_name employee_country  \
# employee_id
# A2R5H9                  Hunman                 Jax               BE
# H8K0L6                    Siff                Tara               GB
# G4R7V0                   Sagal               Gemma               US
# M1Z7U9                  Coates                 Tig               FR
#
#             employee_city      employee_street  employee_street_number
# employee_id
# A2R5H9             Leuven          Grote Markt                       9
# H8K0L6             London         Baker Street                     221
# G4R7V0           New-York         Perry Street                      66
# M1Z7U9              Paris  Rue de l'Université                       7

# %%
contact_columns = ["employee_id", "last_name", "first_name", "emergency_contact", "emergency_contact_number", "relationship"]

# The sheet doesn't have header, so we need to specify the column names, and not setting the first row as header
employee_contact_df = pd.read_excel('./datasets/employee_information.xlsx',
                                    sheet_name='emergency_contacts',
                                    header=None,
                                    names=contact_columns,
                                    index_col='employee_id')
employee_contact_df.head()
# Out:
#             last_name first_name emergency_contact emergency_contact_number  \
# employee_id
# A2R5H9         Hunman        Jax        Opie Hurst          +32-456-5556-84
# H8K0L6           Siff       Tara   Wendy de Matteo         +44-020-5554-333
# G4R7V0          Sagal      Gemma      John Newmark           +1-202-555-194
# M1Z7U9         Coates        Tig       Venus Noone          +1-202-555-0130
#
#             relationship
# employee_id
# A2R5H9           Brother
# H8K0L6            Sister
# G4R7V0           Husband
# M1Z7U9              Wife

# %%
# We import the office's information
office_addresses_df = pd.read_csv('./datasets/office_addresses.csv')
print(office_addresses_df.isna().any())
office_addresses_df
# Out:
# office                  False
# office_country          False
# office_city             False
# office_street           False
# office_street_number    False
# dtype: bool
#           office office_country    office_city   office_street  \
# 0  Leuven Office             BE         Leuven  Martelarenlaan
# 1     ESB Office             US  New York City    Fifth Avenue
# 2  WeWork Office             GB         London      Old Street
#
#    office_street_number
# 0                    38
# 1                   350
# 2                   207

# %%
# Import the employee's roles
employee_roles_df = pd.read_json('./datasets/employee_roles.json',orient='index')
# Name the index column
employee_roles_df.index.name = 'employee_id'
employee_roles_df
# Out:
#                           title monthly_salary               team
# employee_id
# A2R5H9                      CEO          $4500         Leadership
# H8K0L6                      CFO          $4500         Leadership
# G4R7V0       Business Developer          $3000              Sales
# M1Z7U9           Office Manager          $2000  People Operations

# %% [markdown]
# ## II. Proceed to merge data

# %% [markdown]
# We merge the 2 tables to form the Employee Information DataFrame.\
# However, the columns about employees' first name and last name are different between the 2 tables.

# %%
# Rename the columns in the employee_address_df dataframe
employee_address_df.rename(columns={'employee_first_name': 'first_name', 'employee_last_name': 'last_name'}, inplace=True)
employee_information = employee_address_df.merge(employee_contact_df, on=['employee_id', 'first_name', 'last_name'], how='left')
employee_information.head()
# Out:
#             last_name first_name employee_country employee_city  \
# employee_id
# A2R5H9         Hunman        Jax               BE        Leuven
# H8K0L6           Siff       Tara               GB        London
# G4R7V0          Sagal      Gemma               US      New-York
# M1Z7U9         Coates        Tig               FR         Paris
#
#                  employee_street  employee_street_number emergency_contact  \
# employee_id
# A2R5H9               Grote Markt                       9        Opie Hurst
# H8K0L6              Baker Street                     221   Wendy de Matteo
# G4R7V0              Perry Street                      66      John Newmark
# M1Z7U9       Rue de l'Université                       7       Venus Noone
#
#             emergency_contact_number relationship
# employee_id
# A2R5H9               +32-456-5556-84      Brother
# H8K0L6              +44-020-5554-333       Sister
# G4R7V0                +1-202-555-194      Husband
# M1Z7U9               +1-202-555-0130         Wife

# %% [markdown]
# *👉 We can see that only Hunman Jax doesn't have emergy contact*

# %%
# Merge employee_information_df and employee_roles_df on the index
employee_information_roles_df = employee_information.merge(employee_roles_df, on='employee_id', how='left')
employee_information_roles_df.head()
# Out:
#             last_name first_name employee_country employee_city  \
# employee_id
# A2R5H9         Hunman        Jax               BE        Leuven
# H8K0L6           Siff       Tara               GB        London
# G4R7V0          Sagal      Gemma               US      New-York
# M1Z7U9         Coates        Tig               FR         Paris
#
#                  employee_street  employee_street_number emergency_contact  \
# employee_id
# A2R5H9               Grote Markt                       9        Opie Hurst
# H8K0L6              Baker Street                     221   Wendy de Matteo
# G4R7V0              Perry Street                      66      John Newmark
# M1Z7U9       Rue de l'Université                       7       Venus Noone
#
#             emergency_contact_number relationship               title  \
# employee_id
# A2R5H9               +32-456-5556-84      Brother                 CEO
# H8K0L6              +44-020-5554-333       Sister                 CFO
# G4R7V0                +1-202-555-194      Husband  Business Developer
# M1Z7U9               +1-202-555-0130         Wife      Office Manager
#
#             monthly_salary               team
# employee_id
# A2R5H9               $4500         Leadership
# H8K0L6               $4500         Leadership
# G4R7V0               $3000              Sales
# M1Z7U9               $2000  People Operations

# %%
# Similarly, office_df contains different column names with employee_df
# Therefore, we must rename the columns in the office_addresses_df dataframe
employee_information_roles_df.reset_index(inplace=True)
employee_final = employee_information_roles_df.merge(
    office_addresses_df, 
    left_on='employee_country', 
    right_on='office_country',
    how='left')
employee_final
# Out:
#   employee_id last_name first_name employee_country employee_city  \
# 0      A2R5H9    Hunman        Jax               BE        Leuven
# 1      H8K0L6      Siff       Tara               GB        London
# 2      G4R7V0     Sagal      Gemma               US      New-York
# 3      M1Z7U9    Coates        Tig               FR         Paris
#
#        employee_street  employee_street_number emergency_contact  \
# 0          Grote Markt                       9        Opie Hurst
# 1         Baker Street                     221   Wendy de Matteo
# 2         Perry Street                      66      John Newmark
# 3  Rue de l'Université                       7       Venus Noone
#
#   emergency_contact_number relationship               title monthly_salary  \
# 0          +32-456-5556-84      Brother                 CEO          $4500
# 1         +44-020-5554-333       Sister                 CFO          $4500
# 2           +1-202-555-194      Husband  Business Developer          $3000
# 3          +1-202-555-0130         Wife      Office Manager          $2000
#
#                 team         office office_country    office_city  \
# 0         Leadership  Leuven Office             BE         Leuven
# 1         Leadership  WeWork Office             GB         London
# 2              Sales     ESB Office             US  New York City
# 3  People Operations            NaN            NaN            NaN
#
#     office_street  office_street_number
# 0  Martelarenlaan                  38.0
# 1      Old Street                 207.0
# 2    Fifth Avenue                 350.0
# 3             NaN                   NaN

# %% [markdown]
# # III. Cleaning data

# %%
contact_cols = ['emergency_contact','emergency_contact_number',	'relationship']

# %%
# Loop through columns that start with "office"
for column in employee_final.columns:
    if column.startswith('office'):
        employee_final[column].fillna('Remote', inplace=True)
employee_final
# Out:
# C:\Users\Phu\AppData\Local\Temp\ipykernel_1400\2769778809.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Remote' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   employee_final[column].fillna('Remote', inplace=True)
#   employee_id last_name first_name employee_country employee_city  \
# 0      A2R5H9    Hunman        Jax               BE        Leuven
# 1      H8K0L6      Siff       Tara               GB        London
# 2      G4R7V0     Sagal      Gemma               US      New-York
# 3      M1Z7U9    Coates        Tig               FR         Paris
#
#        employee_street  employee_street_number emergency_contact  \
# 0          Grote Markt                       9        Opie Hurst
# 1         Baker Street                     221   Wendy de Matteo
# 2         Perry Street                      66      John Newmark
# 3  Rue de l'Université                       7       Venus Noone
#
#   emergency_contact_number relationship               title monthly_salary  \
# 0          +32-456-5556-84      Brother                 CEO          $4500
# 1         +44-020-5554-333       Sister                 CFO          $4500
# 2           +1-202-555-194      Husband  Business Developer          $3000
# 3          +1-202-555-0130         Wife      Office Manager          $2000
#
#                 team         office office_country    office_city  \
# 0         Leadership  Leuven Office             BE         Leuven
# 1         Leadership  WeWork Office             GB         London
# 2              Sales     ESB Office             US  New York City
# 3  People Operations         Remote         Remote         Remote
#
#     office_street office_street_number
# 0  Martelarenlaan                 38.0
# 1      Old Street                207.0
# 2    Fifth Avenue                350.0
# 3          Remote               Remote

# %% [markdown]
# # III. Subsetting and indexing

# %%
# Subsetting
columns = ["employee_id", "first_name", "last_name", "employee_country", 
                 "employee_city", "employee_street", "employee_street_number", 
                 "emergency_contact", "emergency_contact_number", "relationship", 
                 "monthly_salary", "team", "title", "office", "office_country", 
                 "office_city", "office_street", "office_street_number"]
employee_final = employee_final[columns]
# Setting index
employee_final.set_index('employee_id', inplace=True)
employee_final.head()
# Out:
#             first_name last_name employee_country employee_city  \
# employee_id
# A2R5H9             Jax    Hunman               BE        Leuven
# H8K0L6            Tara      Siff               GB        London
# G4R7V0           Gemma     Sagal               US      New-York
# M1Z7U9             Tig    Coates               FR         Paris
#
#                  employee_street  employee_street_number emergency_contact  \
# employee_id
# A2R5H9               Grote Markt                       9        Opie Hurst
# H8K0L6              Baker Street                     221   Wendy de Matteo
# G4R7V0              Perry Street                      66      John Newmark
# M1Z7U9       Rue de l'Université                       7       Venus Noone
#
#             emergency_contact_number relationship monthly_salary  \
# employee_id
# A2R5H9               +32-456-5556-84      Brother          $4500
# H8K0L6              +44-020-5554-333       Sister          $4500
# G4R7V0                +1-202-555-194      Husband          $3000
# M1Z7U9               +1-202-555-0130         Wife          $2000
#
#                           team               title         office  \
# employee_id
# A2R5H9              Leadership                 CEO  Leuven Office
# H8K0L6              Leadership                 CFO  WeWork Office
# G4R7V0                   Sales  Business Developer     ESB Office
# M1Z7U9       People Operations      Office Manager         Remote
#
#             office_country    office_city   office_street office_street_number
# employee_id
# A2R5H9                  BE         Leuven  Martelarenlaan                 38.0
# H8K0L6                  GB         London      Old Street                207.0
# G4R7V0                  US  New York City    Fifth Avenue                350.0
# M1Z7U9              Remote         Remote          Remote               Remote
